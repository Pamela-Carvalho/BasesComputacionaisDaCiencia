# %%
notas_csv = "7.3 Notas.csv"

f = open(notas_csv, "w", encoding='utf-8')
f.write("""Prova 1,Prova 2,Trabalho
49,75,100
57,74,78
39,64,41
32,58,60
65,92,81
50,67,62
40,69,58
58,80,71
58,75,54
47,70,86
41,59,100
54,80,100
53,76,100
48,75,67
23,40,70
37,43,38
57,75,65
35,58,70
42,59,56
47,58,53
34,48,99
68,84,100
45,74,64
68,87,100
45,73,74
41,53,58
63,80,75
49,63,100
35,51,83
64,85,79
56,79,97
28,56,81
52,70,75
55,76,61
51,77,84
62,80,80
45,69,72
54,75,43
60,77,72
38,52,83
48,69,66
63,81,100
54,78,100
56,71,68
32,54,69
49,65,44
78,100,93
65,84,66
63,81,57
60,80,77
45,62,74
43,63,94
60,73,100
47,69,87
53,64,44
58,81,78
46,74,99
32,45,38
53,75,89
56,75,74
44,66,48
72,97,89
60,74,81
36,65,63
41,57,65
42,70,82
39,70,93
59,69,85
45,65,95
51,72,89
52,61,82
44,54,51
41,59,84
42,60,60
67,87,61
57,77,82
46,66,80
32,58,54
59,84,70
49,66,70
57,70,87
35,57,59
67,92,100
33,51,58
54,81,59
41,61,66
54,72,92
71,96,100
37,55,78
53,71,88
47,63,84
50,71,66
41,57,65
46,62,39
30,42,55
54,76,58
61,81,100
32,50,57
50,77,80
28,46,26
""")
f.close()

import pandas as pd
df = pd.read_csv(notas_csv)
df
# Out:
#     Prova 1  Prova 2  Trabalho
# 0        49       75       100
# 1        57       74        78
# 2        39       64        41
# 3        32       58        60
# 4        65       92        81
# ..      ...      ...       ...
# 95       54       76        58
# 96       61       81       100
# 97       32       50        57
# 98       50       77        80
# 99       28       46        26
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Exercício:
# Modificar o código abaixo para que se o usuário digitou S, ele também deve digitar os pesos da Prova 1, Prova 2 e Trabalho.
#
# ```python
# import pandas as pd
# import numpy as np
#
# df = pd.read_csv(notas_csv)
# opcao = input("Calcular média? Digite S para sim e N para não. ")
#
# if opcao=="S":      # Lembre-se que S precisa ficar entre aspas pois eh uma letra/texto
#   df["Media"] = (df["Prova 1"]+df["Prova 2"]+ df["Trabalho"])/3
#
# df
# ```
#
# Os pesos são números inteiros.
#
# A coluna da média deve calcular a média ponderada com esses pesos.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(notas_csv)
opcao = input("Calcular média? Digite S para sim e N para não. ")

if opcao=="S":      # Lembre-se que S precisa ficar entre aspas pois eh uma letra/texto
    peso_prova1   = int(input("Informe o peso da Prova 1:"))
    peso_prova2   = int(input("Informe o peso da Prova 2:"))
    peso_trabalho = int(input("Informe o peso do Trabalho:"))
    
    df["Media"] = (df["Prova 1"]*peso_prova1+df["Prova 2"]*peso_prova2+ df["Trabalho"]*peso_trabalho)/(peso_prova1 + peso_prova2 + peso_trabalho)

df
# Out:
# Calcular média? Digite S para sim e N para não. S
# Informe o peso da Prova 1:2
# Informe o peso da Prova 2:5
# Informe o peso do Trabalho:4
#     Prova 1  Prova 2  Trabalho      Media
# 0        49       75       100  79.363636
# 1        57       74        78  72.363636
# 2        39       64        41  51.090909
# 3        32       58        60  54.000000
# 4        65       92        81  83.090909
# ..      ...      ...       ...        ...
# 95       54       76        58  65.454545
# 96       61       81       100  84.272727
# 97       32       50        57  49.272727
# 98       50       77        80  73.181818
# 99       28       46        26  35.454545
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Exercício
#
# Modifique o código abaixo para que o usuário tenha que digitar os pesos dos exames no caso em que ele quiser a média ponderada.
#
# ```python
# import pandas as pd
# import numpy as np
#
# df = pd.read_csv(notas_csv)
# opcao = input("Calcular média Simples ou Ponderada (S/P)? ")
#
# if opcao=="S":
#   # media simples
#   df["Media"] = (df["Prova 1"]+df["Prova 2"]+ df["Trabalho"])/3
# else:
#   # media ponderada
#   p1 = 2
#   p2 = 3
#   t = 1
#   total = p1+p2+t
#   df["Media"] = (p1*df["Prova 1"]+p2*df["Prova 2"]+ t*df["Trabalho"])/total
#
# df.head()
# ```
#
# ***Dica:*** Basta modificar as linhas:
# ```
#   p1 = 2
#   p2 = 3
#   t = 1
# ```

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(notas_csv)
opcao = input("Calcular média Simples ou Ponderada (S/P)? ")

if opcao=="S":
  # media simples
  df["Media"] = (df["Prova 1"]+df["Prova 2"]+ df["Trabalho"])/3
else:
  # media ponderada
  p1 = int(input("Informe o peso da Prova 1:"))
  p2 = int(input("Informe o peso da Prova 2:"))
  t  = int(input("Informe o peso do Trabalho:"))
  total = p1+p2+t
  df["Media"] = (p1*df["Prova 1"]+p2*df["Prova 2"]+ t*df["Trabalho"])/total

df.head()
# Out:
# Calcular média Simples ou Ponderada (S/P)? P
# Informe o peso da Prova 1:5
# Informe o peso da Prova 2:6
# Informe o peso do Trabalho:9
#    Prova 1  Prova 2  Trabalho  Media
# 0       49       75       100  79.75
# 1       57       74        78  71.55
# 2       39       64        41  47.40
# 3       32       58        60  52.40
# 4       65       92        81  80.30

# %% [markdown]
# ### Exercício: Planilhas
#
# ```python
# import pandas as pd
# import numpy as np
#
# df = pd.read_csv(notas_csv)
# opcao = input("Calcular média Simples ou Ponderada (S/P)? ")
#
# if opcao=="S":
#   # media simples
#   df["Media"] = (df["Prova 1"]+df["Prova 2"]+ df["Trabalho"])/3
# else:
#   # media ponderada
#   p1 = 2
#   p2 = 3
#   t = 1
#   total = p1+p2+t
#   df["Media"] = (p1*df["Prova 1"]+p2*df["Prova 2"]+ t*df["Trabalho"])/total
#
# df.head()
# ```
#
# Modifique o acima abaixo para que:
#
# * se o usuário digitar S, deve ser calculada a média simples
# * se o usuário digitar P, deve ser calculada a média ponderada com pesos
#   * Peso **2** para a Prova 1,
#   * Peso **3** para a Prova 2 e
#   * Peso **1** para o Trabalho.
# * se usuário não digitar nem S nem P, pedir para o usuário digitar os pesos e calcular a média ponderada.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(notas_csv)
opcao = input("Calcular média Simples ou Ponderada (S/P)? ")

if opcao=="S":
  # media simples
  df["Media"] = (df["Prova 1"]+df["Prova 2"]+ df["Trabalho"])/3
elif opcao=="P":
  # media ponderada
  p1 = 2
  p2 = 3
  t = 1
  total = p1+p2+t
  df["Media"] = (p1*df["Prova 1"]+p2*df["Prova 2"]+ t*df["Trabalho"])/total
else:
  p1 = int(input("Informe o peso da Prova 1:"))
  p2 = int(input("Informe o peso da Prova 2:"))
  t  = int(input("Informe o peso do Trabalho:"))
  total = p1+p2+t
  df["Media"] = (p1*df["Prova 1"]+p2*df["Prova 2"]+ t*df["Trabalho"])/total
df.head()
# Out:
# Calcular média Simples ou Ponderada (S/P)? s
# Informe o peso da Prova 1:5
# Informe o peso da Prova 2:6
# Informe o peso do Trabalho:9
#    Prova 1  Prova 2  Trabalho  Media
# 0       49       75       100  79.75
# 1       57       74        78  71.55
# 2       39       64        41  47.40
# 3       32       58        60  52.40
# 4       65       92        81  80.30

# %% [markdown]
# ### Exercício: Gráficos
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline
#
# a = int(input("Digite o valor de a: "))
# b = int(input("Digite o valor de b: "))
# c = int(input("Digite o valor de c: "))
#
# delta = b*b - 4*a*c
# print("Delta =", delta)
#
# if delta > 0:
#   r1 = (-b - delta**0.5)/(2*a)
#   r2 = (-b + delta**0.5)/(2*a)
#   print("Primeira raiz", r1)
#   print("Segunda raiz", r2)
#
#   lim1 = r1
#   lim2 = r2
#   if r1>r2:
#     lim1 = r2
#     lim2 = r1
# else:
#   r0 = -b/(2*a)
#   lim1 = r0-5
#   lim2 = r0+5
#
# x = np.arange(lim1,lim2,0.01)
# y = a*x*x + b*x + c
# plt.plot(x,y)
# ```
#
# Modifique o código abaixo para que
# * no caso em que exista apenas umas raiz real (delta==0), imprimir a mensagem "Apenas uma raiz real"
# * no caso em que não há raízes reais, imprimir a mensagem "Sem raízes reais".

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

a = int(input("Digite o valor de a: "))
b = int(input("Digite o valor de b: "))
c = int(input("Digite o valor de c: "))

delta = b*b - 4*a*c
print("Delta =", delta)

if delta > 0:
  r1 = (-b - delta**0.5)/(2*a)
  r2 = (-b + delta**0.5)/(2*a)
  print("Primeira raiz", r1)
  print("Segunda raiz", r2)

  lim1 = r1
  lim2 = r2
  if r1>r2:
    lim1 = r2
    lim2 = r1
elif delta == 0:
    print("Uma raiz real")
else:
    print("Não existe raiz real")
    r0 = -b/(2*a)
    lim1 = r0-5
    lim2 = r0+5

x = np.arange(lim1,lim2,0.01)
y = a*x*x + b*x + c
plt.plot(x,y)
# Out:
# Digite o valor de a: 1
# Digite o valor de b: 0
# Digite o valor de c: 0
# Delta = 0
# Uma raiz real
